# %% [markdown]
# <a href="https://colab.research.google.com/github/cc5547/project/blob/main/submission/%EA%B7%B8%EB%9E%98%ED%94%84_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'구분': ['필기응시', '실기응시', '필기합격', '실기합격'],
        '~2017년': [46377014, 29230820, 17506576, 14148567],
        '2018년': [1538327, 1102122, 668114, 532980],
        '2019년': [1676466, 1212193, 758105, 586149],
        '2020년': [1454625, 1150807, 721229, 531203],
        '2021년': [1765798, 1331461, 857339, 630689],
        '2022년': [1604609, 1244344, 751881, 576148]}

df = pd.DataFrame(data)

df.to_csv('data.csv', index=False, encoding='utf-8-sig')

# %%
# !pip install plotly -q

# %%
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# 컴퓨터에서 파일 불러오기
# from google.colab import files
 

# files.upload()

# %%
df_g1 = pd.read_csv('그래프_1.csv')
df_g1
# Out:
#   Unnamed: 0  ~2017년   2018년   2019년   2020년   2021년   2022년
# 0        기술사      9%  10.70%  11.30%   9.30%      8%   7.60%
# 1        기능장  44.80%  47.10%  53.40%  55.30%  56.70%  54.80%
# 2         기사  35.90%     39%  44.40%  46.60%  44.50%  42.90%
# 3       산업기사     32%     37%  38.80%  42.50%     40%  38.40%
# 4       전문사무  59.10%  61.10%  62.40%  70.20%  65.10%  60.30%
# 5        기능사  40.10%  46.20%  46.80%  52.30%  52.10%  51.10%

# %%
from google.colab import files
 

files.upload()
# Out:
#      <input type="file" id="files-81fedec1-5bab-40d8-8538-d9c2c2bcb713" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81fedec1-5bab-40d8-8538-d9c2c2bcb713">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.options.plotting.backend = "plotly"

df_g1 = pd.read_csv('그래프_1.csv')


# 문자열에서 % 기호 제거 및 실수 타입으로 변환
for col in df_g1.columns[1:]:
    df_g1[col] = df_g1[col].apply(lambda x: float(x[:-1]))

fig = go.Figure()

# 연도별 색상 지정
colors = px.colors.qualitative.Set3[:len(df_g1.columns)-1]

for i, col in enumerate(df.columns[1:]):
    fig.add_trace(
        go.Bar(x=df_g1['Unnamed: 0'], y=df_g1[col], name=col, marker_color=colors[i])
        )

# 레이아웃 설정
fig.update_layout(
    title='필기시험 합격률',
    xaxis_title='시험 분류',
    yaxis_title='합격률%',
    yaxis=dict(range=[0, 100]),
    plot_bgcolor='#e2f3ea' # 차트 배경색 지정
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_g2 = pd.read_csv('그래프_2.csv')
df_g2
# Out:
#      구분    ~2017년    2018년    2019년    2020년    2021년    2022년
# 0  필기응시  46377014  1538327  1676466  1454625  1765798  1604609
# 1  실기응시  29230820  1102122  1212193  1150807  1331461  1244344
# 2  필기합격  17506576   668114   758105   721229   857339   751881
# 3  실기합격  14148567   532980   586149   531203   630689   576148

# %%
fig = go.Figure()
df_g2 = df_g2.drop(df_g2.columns[1], axis=1)
years = df_g2.columns[1:]
colors = px.colors.qualitative.Set3[:len(years)] # 연도별 색상 리스트 생성
for i, year in enumerate(years):
    fig.add_trace(go.Bar(x=df_g2['구분'], y=df_g2[year], name=year, marker_color=colors[i]),)

# fig.update_traces(marker_color=colors)
           
# 레이아웃 설정
fig.update_layout(
    title='응시자 및 합격자',
    xaxis_title='시험 분류',
    yaxis_title='인원수',
    # yaxis=dict(range=[0, 50]),
    plot_bgcolor='#e2f3ea', # 차트 배경색 지정
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
